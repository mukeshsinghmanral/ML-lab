# %% [markdown]
# <a href="https://colab.research.google.com/github/mukeshsinghmanral/ML-lab/blob/main/PMCA507P_Week_1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Enter your Details Here:

# %%
Num, Name, Week = input("Reg. Number:"), input("Name:"), input("Week:")
# Out:
# Reg. Number:21312
# Name:sdas
# Week:sdsa

# %% [markdown]
# ### 1.Import the libraries

# %%
import pandas as pd

# %% [markdown]
# ### 2. Import the dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mukeshsinghmanral/ML-lab/main/Week-1.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ### 3.Display the dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ### 4.Drop the unnecessary columns from both `Train` and `Test` datasets

# %%
df=df.drop(columns='Loan_ID')

# %% [markdown]
# ### 5. Hanlde the misssing data

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
gen=df['Gender'].mode()[0]
df['Gender'].fillna(gen,inplace=True)

gen=df['Married'].mode()[0]
df['Married'].fillna(gen,inplace=True)

gen=df['Self_Employed'].mode()[0]
df['Self_Employed'].fillna(gen,inplace=True)

gen=df['Dependents'].mode()[0]
df['Dependents'].fillna(gen,inplace=True)

gen=df['LoanAmount'].mean()
df['LoanAmount'].fillna(gen,inplace=True)

gen=df['Credit_History'].mode()[0]
df['Credit_History'].fillna(gen,inplace=True)

gen=df['Loan_Amount_Term'].mode()[0]
df['Loan_Amount_Term'].fillna(gen,inplace=True)

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    526
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
for i in df.columns:
   print(i ,df[i].nunique())
# Out:
# Gender 2
# Married 2
# Dependents 4
# Education 2
# Self_Employed 2
# ApplicantIncome 505
# CoapplicantIncome 287
# LoanAmount 204
# Loan_Amount_Term 10
# Credit_History 2
# Property_Area 3
# Loan_Status 2

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
categorical_col=['Gender','Married','Dependents','Education','Self_Employed','Loan_Amount_Term','Credit_History','Property_Area','Loan_Status']
df[categorical_col]=df[categorical_col].astype('category')

# %%
X=df.drop(columns='Loan_Status')
y=df[['Loan_Status']]
X
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    category
#  1   Married            614 non-null    category
#  2   Dependents         614 non-null    category
#  3   Education          614 non-null    category
#  4   Self_Employed      614 non-null    category
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    category
#  9   Credit_History     614 non-null    category
#  10  Property_Area      614 non-null    category
# dtypes: category(8), float64(2), int64(1)
# memory usage: 20.6 KB

# %%
for i in df.columns:
   print(i ,df[i].nunique())
# Out:
# Gender 2
# Married 2
# Dependents 4
# Education 2
# Self_Employed 2
# ApplicantIncome 505
# CoapplicantIncome 287
# LoanAmount 204
# Loan_Amount_Term 10
# Credit_History 2
# Property_Area 3
# Loan_Status 2

# %%
X['Self_Employed'].nunique()
# Out:
# 2

# %%
df['Self_Employed'].nunique()
# Out:
# 2

# %% [markdown]
# ### 6. Encode the categorical data

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    category
#  1   Married            614 non-null    category
#  2   Dependents         614 non-null    category
#  3   Education          614 non-null    category
#  4   Self_Employed      614 non-null    category
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    category
#  9   Credit_History     614 non-null    category
#  10  Property_Area      614 non-null    category
# dtypes: category(8), float64(2), int64(1)
# memory usage: 20.6 KB

# %%
label_encode_col=['Gender','Married','Dependents','Education','Self_Employed','Credit_History','Property_Area']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in label_encode_col:
    X[i]=le.fit_transform(X[i])

X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
X['Gender'].unique()
# Out:
# array([1, 0])

# %%
y['Loan_Status']=le.fit_transform(y['Loan_Status'])
# Out:
# <ipython-input-321-731047bd933d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Loan_Status']=le.fit_transform(y['Loan_Status'])

# %%
y[['Loan_Status']]
# Out:
#      Loan_Status
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ..           ...
# 609            1
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %%
X.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162            360.0               1
# 1             1508.0  128.000000            360.0               1
# 2                0.0   66.000000            360.0               1
# 3             2358.0  120.000000            360.0               1
# 4                0.0  141.000000            360.0               1
#
#    Property_Area
# 0              2
# 1              0
# 2              2
# 3              2
# 4              2

# %%
y.head()
# Out:
#    Loan_Status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount Loan_Amount_Term Credit_History  \
# 0                0.0  146.412162            360.0            1.0
# 1             1508.0  128.000000            360.0            1.0
# 2                0.0   66.000000            360.0            1.0
# 3             2358.0  120.000000            360.0            1.0
# 4                0.0  141.000000            360.0            1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
y
# Out:
#      Loan_Status
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ..           ...
# 609            1
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %% [markdown]
# ### 7.Split the Train & Test datasets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=72)

# %%
X_train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 299       1        1           1          0              0             2014
# 388       1        1           0          0              0             2333
# 543       1        1           1          1              0             2239
# 183       1        1           1          0              0            33846
# 340       1        1           3          1              0             2647
# ..      ...      ...         ...        ...            ...              ...
# 282       1        1           2          0              0             2301
# 207       1        0           0          1              0             3975
# 74        1        1           3          0              1             5266
# 46        1        1           1          0              0             5649
# 472       1        1           3          0              0             4691
#
# ...

# %%
y_train
# Out:
#      Loan_Status
# 299            0
# 388            1
# 543            1
# 183            0
# 340            0
# ..           ...
# 282            1
# 207            1
# 74             1
# 46             1
# 472            1
#
# [491 rows x 1 columns]

# %% [markdown]
# ### 8. Do Feature Scaling if required

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

Col_Scale=['ApplicantIncome',	'CoapplicantIncome',	'LoanAmount']

for i in Col_Scale:
    X_train[i]=sc.fit_transform(X_train[[i]])

# %%
X_train.replace("3+",3,inplace=True)

# %%
X_train.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 299       1        1           1          0              0        -0.552253
# 388       1        1           0          0              0        -0.501701
# 543       1        1           1          1              0        -0.516597
# 183       1        1           1          0              0         4.492186
# 340       1        1           3          1              0        -0.451941
#
#      CoapplicantIncome  LoanAmount Loan_Amount_Term  Credit_History  \
# 299           0.469776   -0.408589            360.0               1
# 388           0.286743   -0.132980            360.0               1
# 543           0.325295   -0.228844            360.0               1
# 183          -0.584104    1.352911            360.0               1
# 340          -0.012307    0.310390            360.0               1
#
#      Property_Area
# 299              2
# 388              2
# 543              2
# ...

# %%
X_train.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 299       1        1           1          0              0        -0.552253
# 388       1        1           0          0              0        -0.501701
# 543       1        1           1          1              0        -0.516597
# 183       1        1           1          0              0         4.492186
# 340       1        1           3          1              0        -0.451941
#
#      CoapplicantIncome  LoanAmount Loan_Amount_Term  Credit_History  \
# 299           0.469776   -0.408589            360.0               1
# 388           0.286743   -0.132980            360.0               1
# 543           0.325295   -0.228844            360.0               1
# 183          -0.584104    1.352911            360.0               1
# 340          -0.012307    0.310390            360.0               1
#
#      Property_Area
# 299              2
# 388              2
# 543              2
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491 entries, 299 to 472
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             491 non-null    int64
#  1   Married            491 non-null    int64
#  2   Dependents         491 non-null    int64
#  3   Education          491 non-null    int64
#  4   Self_Employed      491 non-null    int64
#  5   ApplicantIncome    491 non-null    float64
#  6   CoapplicantIncome  491 non-null    float64
#  7   LoanAmount         491 non-null    float64
#  8   Loan_Amount_Term   491 non-null    category
#  9   Credit_History     491 non-null    int64
#  10  Property_Area      491 non-null    int64
# dtypes: category(1), float64(3), int64(7)
# memory usage: 43.0 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 206 to 44
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             123 non-null    int64
#  1   Married            123 non-null    int64
#  2   Dependents         123 non-null    int64
#  3   Education          123 non-null    int64
#  4   Self_Employed      123 non-null    int64
#  5   ApplicantIncome    123 non-null    int64
#  6   CoapplicantIncome  123 non-null    float64
#  7   LoanAmount         123 non-null    float64
#  8   Loan_Amount_Term   123 non-null    category
#  9   Credit_History     123 non-null    int64
#  10  Property_Area      123 non-null    int64
# dtypes: category(1), float64(2), int64(8)
# memory usage: 11.1 KB

# %% [markdown]
# ### 9. Apply dimensionality reduction if required

# %% [markdown]
# ### 10. Train the required model

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(X_train,y_train)
pred_Y=model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
X_new=df.iloc[:,:-1]
y_new=df.iloc[:,-1]

# %%
X_new.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount Loan_Amount_Term Credit_History Property_Area
# 0                0.0  146.412162            360.0            1.0         Urban
# 1             1508.0  128.000000            360.0            1.0         Rural
# 2                0.0   66.000000            360.0            1.0         Urban
# 3             2358.0  120.000000            360.0            1.0         Urban
# 4                0.0  141.000000            360.0            1.0         Urban

# %%
y_new.head()
# Out:
# 0    Y
# 1    N
# 2    Y
# 3    Y
# 4    Y
# Name: Loan_Status, dtype: category
# Categories (2, object): ['N', 'Y']

# %%
X_train,X_test,y_train,y_test=train_test_split(X_new,y_new,test_size=.2,random_state=72)

# %%
from sklearn.tree import DecisionTreeClassifier

model=DecisionTreeClassifier()

model.fit(X_train,y_train)

predY=model.predict(X_test)

# %% [markdown]
# ### 11. Check the Model Performance()

# %%
from sklearn.metrics import accuracy_score

pred=accuracy_score(y_test,pred_Y)
print(pred)
# Out:
# 0.5284552845528455

# %%
pred=accuracy_score(y_test,predY)
print(pred)
# Out:
# 0.17886178861788618

# %% [markdown]
# ### 12. Fine tune the model if required.

# %% [markdown]
# ### 13. Write Down your inferences.

# %% [markdown]
# # For uploading you need to execute the follwing script

# %%
from google.colab import auth
auth.authenticate_user()
import requests
gcloud_token = !gcloud auth print-access-token
gcloud_tokeninfo = requests.get('https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]).json()
user = gcloud_tokeninfo['email']
import datetime
dt = datetime.datetime.now()
x = str(dt).split('.')[0]
print(f"This Script is executed by: ",user, "at", x)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-338-15f4d47c5399> in <cell line: 2>()
#       1 from google.colab import auth
# ----> 2 auth.authenticate_user()
#       3 import requests
#       4 gcloud_token = get_ipython().getoutput('gcloud auth print-access-token')
#       5 gcloud_tokeninfo = requests.get('https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]).json()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     279   if not _check_adc(_CredentialType.USER):
#     280     if use_auth_ephem:
# --> 281       _message.blocking_request(
#     282           'request_auth',
#     283           request={'authType': 'auth_user_ephemeral'},
#
# ...
